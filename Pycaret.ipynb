# %%
from pycaret.datasets import get_data
df=get_data(dataset='traffic')
# Out:
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  Rush Hour  \
# 0     NaN  288.28      0.0      0.0          40       Clouds          1
# 1     NaN  289.36      0.0      0.0          75       Clouds          0
# 2     NaN  289.58      0.0      0.0          90       Clouds          0
# 3     NaN  290.13      0.0      0.0          90       Clouds          0
# 4     NaN  291.14      0.0      0.0          75       Clouds          0
#
#    traffic_volume
# 0            5545
# 1            4516
# 2            4767
# 3            5026
# 4            4918

# %%
from pycaret.regression import*

# %%
s=setup(df,target='traffic_volume',session_id=123)
# Out:
# <style type="text/css">
# #T_20c2b_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_20c2b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20c2b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_20c2b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20c2b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20c2b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_20c2b_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_20c2b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_20c2b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_20c2b_row1_col1" class="data row1 col1" >traffic_volume</td>
#     </tr>
#     <tr>
#       <th id="T_20c2b_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model=compare_models()
# Out:
# <style type="text/css">
# #T_ea72e th {
#   text-align: left;
# }
# ...

# %%
final_model = finalize_model(best_model)
save_model(final_model, 'best_traffic_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['temp', 'rain_1h', 'snow_1h',
#                                               'clouds_all', 'Rush Hour'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['holiday', 'weather_main'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('onehot_encoding',
#                   TransformerWrapper(inclu...
#                                feature_types=None, gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('smsspamcollection.tsv',sep='\t')

# %%
df.sample(5)
# Out:
#      label                                            message  length  punct
# 3237   ham  Aight text me when you're back at mu and I'll ...      92      3
# 843    ham  Our Prashanthettan's mother passed away last n...      76      3
# 3521   ham  No it will reach by 9 only. She telling she wi...      70      2
# 2123   ham                       Do you know when the result.      28      1
# 738   spam  Hi. Customer Loyalty Offer:The NEW Nokia6650 M...     148      9

# %%
from pycaret.classification import*

# %%
df=df.drop(columns=['length','punct'])

# %%
df.sample(5)
# Out:
#      label                                            message
# 664    ham        Leave it de:-). Start Prepare for next:-)..
# 748   spam  U are subscribed to the best Mobile Content Se...
# 2030   ham             Thanx but my birthday is over already.
# 1554   ham               Ok how you dear. Did you call chechi
# 2190   ham  Yup i shd haf ard 10 pages if i add figures......

# %%
s=setup(df,target='label',session_id=123)
# Out:
# <style type="text/css">
# #T_5f3b1_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5f3b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f3b1_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5f3b1_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f3b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5f3b1_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5f3b1_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_5f3b1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5f3b1_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5f3b1_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_5f3b1_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best=compare_models()
# Out:
# <style type="text/css">
# #T_9bd5e th {
#   text-align: left;
# }
# #T_9bd5e_row0_col0, #T_9bd5e_row1_col0, #T_9bd5e_row1_col2, #T_9bd5e_row2_col0, #T_9bd5e_row3_col0, #T_9bd5e_row3_col2, #T_9bd5e_row4_col0, #T_9bd5e_row5_col0, #T_9bd5e_row6_col0, #T_9bd5e_row6_col2, #T_9bd5e_row7_col0, #T_9bd5e_row8_col0, #T_9bd5e_row8_col2, #T_9bd5e_row9_col0, #T_9bd5e_row9_col2, #T_9bd5e_row10_col0, #T_9bd5e_row11_col0, #T_9bd5e_row12_col0, #T_9bd5e_row12_col2, #T_9bd5e_row13_col0, #T_9bd5e_row13_col2, #T_9bd5e_row14_col0, #T_9bd5e_row14_col1, #T_9bd5e_row14_col2, #T_9bd5e_row14_col3, #T_9bd5e_row14_col4, #T_9bd5e_row14_col5, #T_9bd5e_row14_col6, #T_9bd5e_row14_col7 {
#   text-align: left;
# }
# ...

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predict_model(best)

# %%
new_data=df.copy().drop('label',axis=1)

# %%
prediction=predict_model(best,data=new_data)

# %%
prediction

# %%
save_model(best,'best_pipeline')
